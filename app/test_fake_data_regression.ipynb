# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from supervised_learning.polynomial_regression import PolynomialRegression

from sklearn.model_selection import train_test_split

df = pd.read_csv('../data/fake-data-poly.csv')

# %%
X=df.drop('y',axis=1)
y=df['y']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
# to numpy
X_train = X_train.to_numpy().reshape(-1,1)
X_test = X_test.to_numpy().reshape(-1,1)
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((140, 1), (61, 1), (140,), (61,))

# %%
plt.scatter(X_train, y_train)
plt.show()

# %%
model = PolynomialRegression(5000000,1e-9,2)
# X_train = X_train.reshape(-1,1)
# X_train.shape
# model.w.shape, X_train.shape, y_train.shape
model.fit(X_train, y_train)
# 看一下training_errors
plt.plot(model.training_errors)

# %%
# 生成一系列用于绘制拟合曲线的x值
x_values = np.linspace(X_train.min(), X_train.max(), 100).reshape(-1, 1)

# 使用模型的权重生成拟合曲线的y值
y_values = np.polyval(model.w[::-1], x_values)  # 注意要逆序权重数组

# 绘制拟合曲线
plt.scatter(X_train, y_train, label='Training Data')
plt.plot(x_values, y_values, color='red', label='Polynomial Fit')
plt.xlabel('House Age')
plt.ylabel('House Price')
plt.title('Polynomial Regression Fit')
plt.legend()
plt.show()
model.w, model.b
# Out:
# (array([ 0.43541148, -4.0121835 ,  0.02591338]), -0.04234745644329174)

# %%
# check weights and bias
model.w, model.b
# Out:
# (array([ 0.43541148, -4.0121835 ,  0.02591338]), -0.04234745644329174)
